# %%
# %load_ext autoreload
# %autoreload 2
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
from utils.functions import ingest_to_bronze
from config.paths import DATASETS
from tests.test_ingestion import test_table_exists

for table, path in DATASETS.items():
    ingest_to_bronze(spark,path,table)
    test_table_exists(spark, table)
