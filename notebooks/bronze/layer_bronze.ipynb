# %%
location_file="/Volumes/workspace/raw_divvy/raw_file/riders.csv"
df=spark.read.format("csv").option("header","false").option("inferSchema","true").load(location_file)
df.write.format("delta").mode("overwrite").saveAsTable("db_project_divvy_bronze.riders")
display(df)
